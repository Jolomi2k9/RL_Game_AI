# %% [markdown]
# ### Importing the libraries

# %%
from typing import Callable, Dict, List, Optional, Tuple, Type, Union, Any

import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torch as th

from stable_baselines3 import PPO
from stable_baselines3 import DQN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecTransposeImage
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback

# %%
#!cd github & git clone https://github.com/mwydmuch/ViZDoom.git

# %% [markdown]
# ### Importing  OpenAI and Doom Dependencies

# %%
from vizdoom import *
import random
import time
import gym
from gym import Env
from gym.spaces import Discrete, Box
import cv2

# %% [markdown]
# ## Game Setup

# %% [markdown]
# ### VizDoom

# %%
#Creating a game instance
game = DoomGame()
#Load our desired Doom configurations 
game.load_config('github/ViZDoom/scenarios/basic.cfg')
#starting up the game
#game.init()
# Out:
# True

# %% [markdown]
# ## Wrapping and defining our environment

# %% [markdown]
# ### VizDoom

# %%
#Define our vizdoom environment class
class VizDoomGym(Env):
    #Initialize our environment
    def __init__(self, render=False):
        #inherit from env base class
        super().__init__()
        self.game = DoomGame()
        #This allows us to load up our configurations which defines our maps,rewards,buttons etc...
        self.game.load_config('github/ViZDoom/scenarios/basic.cfg')
        
        
        #Determine if to render game window
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        #start up the game
        self.game.init()
        
        #create our observation space.
        #We want the same of the observation space to match the game frame exactly- 
        #This is what is used to establish the parameters for the underlying models.
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
        #define our action space
        self.action_space = Discrete(3)
    #take step in environment
    def step(self, action):
        #Define the action to take
        actions = np.identity(3, dtype=np.uint8)
        #this actions will be a matrix defining if the agent go left,
        #right or shoot and also our frame skip parameter
        reward = self.game.make_action(actions[action],4)        
        
        #return numpy zeroes array if nothing is returned
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            #gray scaling the captured image
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0      
        
        
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info
    #render game 
    def render():
        pass    
    def reset(self):
        self.game.new_episode()        
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    #grayscale and resize the image
    def grayscale(self, observation):
        #take the observation, grab the color channel and move it to the end
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    #close the game
    def close(self):
        #self.game.close()
        pass

# %% [markdown]
# ### Verify our environment

# %%
#import environment checker
from stable_baselines3.common import env_checker

# %%
env = VizDoomGym(render=True)

# %%
env_checker.check_env(env)

# %%
env.close()

# %%
#create our environment without rendering it
env = VizDoomGym()

# %% [markdown]
# ### Defining custom DQN Network

# %%
class CustomCNN(BaseFeaturesExtractor):
    
    
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        super(CustomCNN, self).__init__(observation_space, features_dim)
        # We assume CxHxW images (channels first)
        # Re-ordering will be done by pre-preprocessing or wrapper
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with th.no_grad():
            n_flatten = self.cnn(
                th.as_tensor(observation_space.sample()[None]).float()
            ).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))
    

policy_kwargs = dict(
    features_extractor_class=CustomCNN,    
)

# %% [markdown]
# ### Setting up Callback

# %%
class TrainingAndLoggingCallback(BaseCallback):
    
   
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainingAndLoggingCallback, self). __init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
CHECKPOINT_DIR = './train/train_basic3'
LOG_DIR = './train/log_basic3'

# %%
callback = TrainingAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ### Create and Train model

# %%
 model = DQN("CnnPolicy", env, buffer_size = 320000,batch_size = 64, policy_kwargs=policy_kwargs,
             verbose=1,optimize_memory_usage = True, learning_rate=0.001)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000,callback=callback)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.8     |
# |    ep_rew_mean      | -252     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 656      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 748      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 804      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 862      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.5     |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 896      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 771      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41       |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 941      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 985      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.7     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 864      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 874      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.8     |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 889      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.8     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 907      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 877      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | -145     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 832      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 826      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.1     |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 660      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.2     |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 680      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.5     |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 692      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.7     |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 710      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 731      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.8     |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 744      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.2     |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 752      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40       |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 761      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 777      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 783      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.2     |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 787      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.3     |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 786      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.1     |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 799      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.7     |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 799      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.1     |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 806      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 810      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.6     |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 814      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.3     |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 818      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.8     |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 825      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 829      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 834      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 842      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 846      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -98.1    |
# |    exploration_rate | 0.475    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 847      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.5     |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 854      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.435    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 860      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.9     |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 862      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 863      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 867      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.9     |
# |    ep_rew_mean      | -99      |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 872      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | -90.5    |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 835      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -90.9    |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 840      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.4     |
# |    ep_rew_mean      | -83.7    |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 839      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.4     |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 844      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -80.6    |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 847      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 851      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | -78.8    |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 850      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | -78      |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 852      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | -84.5    |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 854      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | -91.8    |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 858      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | -98.6    |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 862      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.222    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 864      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 849      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 853      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 854      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 857      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.8     |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 853      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.3     |
# |    ep_rew_mean      | -94.6    |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 852      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.137    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 852      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | -97      |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 852      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | -92.2    |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 849      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.2     |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.096    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 848      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | -97.5    |
# |    exploration_rate | 0.0844   |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 848      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.4     |
# |    ep_rew_mean      | -99.8    |
# |    exploration_rate | 0.0696   |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 850      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | -92.8    |
# |    exploration_rate | 0.0631   |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 839      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | -92.6    |
# |    exploration_rate | 0.0594   |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 838      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | -92.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 837      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | -97.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 834      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | -85.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 830      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | -85.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 831      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | -84.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 834      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | -86.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 835      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.3     |
# |    ep_rew_mean      | -82.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 837      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.5     |
# |    ep_rew_mean      | -84.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 813      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 10809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.3     |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 817      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.1     |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 819      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | -81.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 824      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.1     |
# |    ep_rew_mean      | -83.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 826      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.9     |
# |    ep_rew_mean      | -82.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 827      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | -79.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 830      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | -71.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 830      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | -69.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 832      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.8     |
# |    ep_rew_mean      | -74.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 834      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | -68.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 835      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | -67.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 838      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | -68.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 840      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | -69.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 842      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | -76.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 846      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 12723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | -72.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 847      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 12824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.7     |
# |    ep_rew_mean      | -80.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 850      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | -93.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 854      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 856      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.3     |
# |    ep_rew_mean      | -96.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 858      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.2     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 858      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 13756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 859      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 13961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 861      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 861      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 863      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 860      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -89.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 859      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | -92.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 861      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -89      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 864      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 859      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | -83.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 861      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.3     |
# |    ep_rew_mean      | -80.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 859      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | -91.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 862      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | -90.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 863      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -87.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 864      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | -89.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 865      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -95.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 868      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 15696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.5     |
# |    ep_rew_mean      | -98.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 869      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 15873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.6     |
# |    ep_rew_mean      | -93.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 869      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 15957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | -89.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 871      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | -89.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 872      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 874      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.7     |
# |    ep_rew_mean      | -81.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 876      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | -74.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 876      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | -67.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 876      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | -68.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 879      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 16805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | -61.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 880      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 16886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | -60.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 881      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 16986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | -63.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# ...
# |    time_elapsed     | 790      |
# |    total_timesteps  | 87469    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.84     |
# |    n_updates        | 9367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 110      |
# |    time_elapsed     | 792      |
# |    total_timesteps  | 87550    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.91     |
# |    n_updates        | 9387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3180     |
# |    fps              | 110      |
# |    time_elapsed     | 796      |
# |    total_timesteps  | 87729    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.35     |
# |    n_updates        | 9432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 5.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3184     |
# |    fps              | 110      |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 87815    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.27     |
# |    n_updates        | 9453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 6.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3188     |
# |    fps              | 109      |
# |    time_elapsed     | 799      |
# |    total_timesteps  | 87896    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.9      |
# |    n_updates        | 9473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 6.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3192     |
# |    fps              | 109      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 87978    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.9      |
# |    n_updates        | 9494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 8.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3196     |
# |    fps              | 109      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 87986    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.946    |
# |    n_updates        | 9496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3200     |
# |    fps              | 109      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 88143    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.91     |
# |    n_updates        | 9535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3204     |
# |    fps              | 109      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 88157    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.18     |
# |    n_updates        | 9539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3208     |
# |    fps              | 109      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 88219    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.42     |
# |    n_updates        | 9554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -2.23    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3212     |
# |    fps              | 109      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 88372    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.38     |
# |    n_updates        | 9592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -2.11    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3216     |
# |    fps              | 109      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 88380    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.09     |
# |    n_updates        | 9594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -2.51    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3220     |
# |    fps              | 109      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 88402    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.34     |
# |    n_updates        | 9600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | -3.54    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3224     |
# |    fps              | 108      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 88492    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.05     |
# |    n_updates        | 9622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3228     |
# |    fps              | 108      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 88500    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.547    |
# |    n_updates        | 9624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3232     |
# |    fps              | 108      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 88525    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.4      |
# |    n_updates        | 9631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3236     |
# |    fps              | 108      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 88635    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.51     |
# |    n_updates        | 9658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3240     |
# |    fps              | 108      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 88655    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.713    |
# |    n_updates        | 9663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3244     |
# |    fps              | 108      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 88693    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.71     |
# |    n_updates        | 9673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3248     |
# |    fps              | 108      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 88774    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.62     |
# |    n_updates        | 9693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3252     |
# |    fps              | 108      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 88855    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.85     |
# |    n_updates        | 9713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3256     |
# |    fps              | 108      |
# |    time_elapsed     | 821      |
# |    total_timesteps  | 88943    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.78     |
# |    n_updates        | 9735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3260     |
# |    fps              | 108      |
# |    time_elapsed     | 822      |
# |    total_timesteps  | 88959    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.12     |
# |    n_updates        | 9739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3264     |
# |    fps              | 108      |
# |    time_elapsed     | 822      |
# |    total_timesteps  | 88969    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.98     |
# |    n_updates        | 9742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3268     |
# |    fps              | 108      |
# |    time_elapsed     | 824      |
# |    total_timesteps  | 89055    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.91     |
# |    n_updates        | 9763     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-3000ab6e0ff5> in <module>
# ----> 1 model.learn(total_timesteps=100000,callback=callback)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     256     ) -> OffPolicyAlgorithm:
#     257
# --> 258         return super(DQN, self).learn(
#     259             total_timesteps=total_timesteps,
#     260             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     352
#     353         while self.num_timesteps < total_timesteps:
# --> 354             rollout = self.collect_rollouts(
#     355                 self.env,
#     356                 train_freq=self.train_freq,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     585
#     586             # Rescale and perform action
# --> 587             new_obs, rewards, dones, infos = env.step(actions)
#     588
#     589             self.num_timesteps += env.num_envs
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      41     def step_wait(self) -> VecEnvStepReturn:
#      42         for env_idx in range(self.num_envs):
# ---> 43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44                 self.actions[env_idx]
#      45             )
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      88         if self.needs_reset:
#      89             raise RuntimeError("Tried to step environment that needs reset")
# ---> 90         observation, reward, done, info = self.env.step(action)
#      91         self.rewards.append(reward)
#      92         if done:
#
# <ipython-input-5-a4a9c0cf1543> in step(self, action)
#      31         #this actions will be a matrix defining if the agent go left,
#      32         #right or shoot and also our frame skip parameter
# ---> 33         reward = self.game.make_action(actions[action],4)
#      34
#      35         #return numpy zeroes array if nothing is returned
#
# KeyboardInterrupt:

# %% [markdown]
# ## Optuna for hyperparameter tuning

# %% [markdown]
# ### Dependencies for optuna

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler

# %% [markdown]
# ### Optuna variables

# %%
N_TRIALS = 100
N_STARTUP_TRIALS = 10
N_EVALUATIONS = 2
N_TIMESTEPS = int(2e4)
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_EPISODES = 3
DEFAULT_HYPERPARAMS = {
    "policy": "CnnPolicy",
    "env": env,
}

# %% [markdown]
# ### Optuna Sampler

# %%
def sample_DQN_params(trial: optuna.Trial) -> Dict[str, Any]:
    
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    buffer_size = trial.suggest_categorical("buffer_size ",[int(1e3),int(1e4),int(1e5)])    
    learning_rate = trial.suggest_float("lr", 1e-5, 1, log=True)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64,128])    
    net_arch = trial.suggest_categorical("net_arch", ["tiny", "small"])
    activation_fn = trial.suggest_categorical("activation_fn", ["tanh", "relu"])
    seed  = trial.suggest_categorical("seed ", [1, 2,3,4,5])
    optimize_memory_usage = True

    # Display true values
    trial.set_user_attr("gamma_", gamma)    

    net_arch = [
        16,32 if net_arch == "tiny" else 32,32,32
    ]

    activation_fn = { "relu": nn.ReLU, "tanh": nn.Tanh,}[activation_fn]

    return {        
        "gamma": gamma,
        "buffer_size": buffer_size,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "max_grad_norm": max_grad_norm,
        "optimize_memory_usage": optimize_memory_usage,
        "policy_kwargs": {
            "net_arch": net_arch,
            "activation_fn": activation_fn,            
        },
    }

# %% [markdown]
# ### Callback for evaluating trial

# %%
class TrialEvalCallback(EvalCallback):
    
    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        deterministic: bool = True,
        verbose: int = 0,
    ):

        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            super()._on_step()
            self.eval_idx += 1
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %% [markdown]
# ### Model Tuning

# %%
def objective(trial: optuna.Trial) -> float:

    kwargs = DEFAULT_HYPERPARAMS.copy()
    # Sample hyperparameters
    kwargs.update(sample_DQN_params(trial))
    # Create our model
    model = DQN(**kwargs)
    # Wrapping env used for evaluation
    eval_env = Monitor(env)
    eval_env = DummyVecEnv([lambda: eval_env])
    eval_env = VecTransposeImage(eval_env)    
    # Create the callback that will periodically evaluate
    # and report the performance
    eval_callback = TrialEvalCallback(
        eval_env, trial, n_eval_episodes=N_EVAL_EPISODES, eval_freq=EVAL_FREQ, deterministic=True
    )

    nan_encountered = False
    try:
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN
        print(e)
        nan_encountered = True
    finally:
        # Free memory
        model.env.close()
        eval_env.close()

    # Tell the optimizer that the trial failed
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward


if __name__ == "__main__":
    # Set pytorch num threads to 1 for faster training
    torch.set_num_threads(1)

    sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
    # Do not prune before 1/3 of the max budget is used
    pruner = MedianPruner(n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3)

    study = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize")
    try:
        study.optimize(objective, n_trials=N_TRIALS, timeout=600)
    except KeyboardInterrupt:
        pass

    print("Number of finished trials: ", len(study.trials))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: ", trial.value)

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

    print("  User attrs:")
    for key, value in trial.user_attrs.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2022-04-19 22:48:33,765] A new study created in memory with name: no-name-db4344f9-1bdf-4fb4-a5ba-c905241cd224
# [I 2022-04-19 22:48:56,484] Trial 0 finished with value: -300.0 and parameters: {'gamma': 0.0009650797921447411, 'buffer_size ': 1000, 'lr': 0.04056457586217798, 'max_grad_norm': 4.269871692268495, 'batch_size': 64, 'net_arch': 'tiny', 'activation_fn': 'relu', 'seed ': 2}. Best is trial 0 with value: -300.0.
# [I 2022-04-19 22:49:20,502] Trial 1 finished with value: -300.0 and parameters: {'gamma': 0.0020954332430213047, 'buffer_size ': 100000, 'lr': 7.401715439223582e-05, 'max_grad_norm': 2.7585881320921772, 'batch_size': 32, 'net_arch': 'tiny', 'activation_fn': 'relu', 'seed ': 4}. Best is trial 0 with value: -300.0.
# [I 2022-04-19 22:49:44,216] Trial 2 finished with value: -300.0 and parameters: {'gamma': 0.0755636059450642, 'buffer_size ': 100000, 'lr': 0.10040713616491531, 'max_grad_norm': 0.8752237129600708, 'batch_size': 64, 'net_arch': 'tiny', 'activation_fn': 'relu', 'seed ': 3}. Best is trial 0 with value: -300.0.
# [I 2022-04-19 22:50:07,684] Trial 3 finished with value: -300.0 and parameters: {'gamma': 0.09652995241659242, 'buffer_size ': 10000, 'lr': 0.0018009597932535583, 'max_grad_norm': 0.9356543576456269, 'batch_size': 64, 'net_arch': 'tiny', 'activation_fn': 'relu', 'seed ': 3}. Best is trial 0 with value: -300.0.
# [I 2022-04-19 22:50:29,620] Trial 4 finished with value: -300.0 and parameters: {'gamma': 0.0007424570489347396, 'buffer_size ': 10000, 'lr': 0.00011265435902404214, 'max_grad_norm': 3.869043164478262, 'batch_size': 128, 'net_arch': 'tiny', 'activation_fn': 'relu', 'seed ': 1}. Best is trial 0 with value: -300.0.
# [I 2022-04-19 22:50:48,950] Trial 5 finished with value: -73.33333333333333 and parameters: {'gamma': 0.00576031317402937, 'buffer_size ': 1000, 'lr': 0.021711087686900554, 'max_grad_norm': 1.8940136707799116, 'batch_size': 128, 'net_arch': 'tiny', 'activation_fn': 'tanh', 'seed ': 3}. Best is trial 5 with value: -73.33333333333333.
# [I 2022-04-19 22:51:07,753] Trial 6 finished with value: 95.0 and parameters: {'gamma': 0.0021813151695808546, 'buffer_size ': 100000, 'lr': 0.00015581771449402266, 'max_grad_norm': 2.8095652180149444, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:51:27,254] Trial 7 finished with value: 95.0 and parameters: {'gamma': 0.0026003433673736703, 'buffer_size ': 10000, 'lr': 0.00020826201986394438, 'max_grad_norm': 1.505639624807979, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:51:46,470] Trial 8 finished with value: -79.66666666666667 and parameters: {'gamma': 0.009247546506615533, 'buffer_size ': 1000, 'lr': 0.021713187455780093, 'max_grad_norm': 1.3907322944009253, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 5}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:52:08,674] Trial 9 finished with value: -300.0 and parameters: {'gamma': 0.00010331281426239379, 'buffer_size ': 100000, 'lr': 0.7876764066152399, 'max_grad_norm': 3.8529662958448827, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 5}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:52:30,729] Trial 10 finished with value: -300.0 and parameters: {'gamma': 0.017243428670872443, 'buffer_size ': 100000, 'lr': 1.9783465616976416e-05, 'max_grad_norm': 0.3150885637256447, 'batch_size': 32, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:52:53,906] Trial 11 finished with value: -300.0 and parameters: {'gamma': 0.0003167341938148409, 'buffer_size ': 10000, 'lr': 0.0006970848127035999, 'max_grad_norm': 2.0441280741726033, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:53:14,340] Trial 12 finished with value: -241.66666666666666 and parameters: {'gamma': 0.0022137607613573764, 'buffer_size ': 10000, 'lr': 0.0004315965965978234, 'max_grad_norm': 0.6015468255453507, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:53:32,962] Trial 13 finished with value: 95.0 and parameters: {'gamma': 0.02298551315457608, 'buffer_size ': 100000, 'lr': 1.2528712027822e-05, 'max_grad_norm': 2.2547441701584297, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:53:55,765] Trial 14 finished with value: -300.0 and parameters: {'gamma': 0.0035783122348732057, 'buffer_size ': 10000, 'lr': 0.0001576568450637771, 'max_grad_norm': 1.3783408843222544, 'batch_size': 32, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 4}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:54:14,984] Trial 15 finished with value: -73.33333333333333 and parameters: {'gamma': 0.000858715584533601, 'buffer_size ': 100000, 'lr': 0.002840584370357545, 'max_grad_norm': 2.7225096780610865, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 2}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:54:39,439] Trial 16 finished with value: -300.0 and parameters: {'gamma': 0.00025661602669187824, 'buffer_size ': 10000, 'lr': 4.55140293256842e-05, 'max_grad_norm': 0.513141687125104, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:55:01,807] Trial 17 finished with value: -300.0 and parameters: {'gamma': 0.01924083222062138, 'buffer_size ': 100000, 'lr': 1.0393859817383813e-05, 'max_grad_norm': 2.6549373866817128, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:55:25,022] Trial 18 finished with value: -300.0 and parameters: {'gamma': 0.03605004499831373, 'buffer_size ': 100000, 'lr': 3.278321185701553e-05, 'max_grad_norm': 2.054025371675688, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:55:48,321] Trial 19 finished with value: -300.0 and parameters: {'gamma': 0.010845261452392398, 'buffer_size ': 100000, 'lr': 1.0445035523908048e-05, 'max_grad_norm': 4.73645517742704, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 2}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:56:09,482] Trial 20 finished with value: -241.66666666666666 and parameters: {'gamma': 0.003822337955868364, 'buffer_size ': 10000, 'lr': 0.0003820304801835864, 'max_grad_norm': 0.9891741055414119, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 5}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:56:31,761] Trial 21 finished with value: -300.0 and parameters: {'gamma': 0.001510076673178231, 'buffer_size ': 100000, 'lr': 0.0001760927375064167, 'max_grad_norm': 1.6576955475104158, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:56:54,020] Trial 22 finished with value: -300.0 and parameters: {'gamma': 0.0059279190517202065, 'buffer_size ': 100000, 'lr': 0.0009888482334375096, 'max_grad_norm': 3.224416401711607, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:57:13,529] Trial 23 finished with value: -73.33333333333333 and parameters: {'gamma': 0.030628253796862227, 'buffer_size ': 1000, 'lr': 0.0002708033511488799, 'max_grad_norm': 2.336814939218411, 'batch_size': 32, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:57:35,399] Trial 24 finished with value: -300.0 and parameters: {'gamma': 0.0012590685546342623, 'buffer_size ': 100000, 'lr': 0.007102015368483064, 'max_grad_norm': 1.6098356436343626, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:57:54,520] Trial 25 finished with value: -73.33333333333333 and parameters: {'gamma': 0.005630025133523602, 'buffer_size ': 10000, 'lr': 5.899082903004146e-05, 'max_grad_norm': 1.1354562766442862, 'batch_size': 128, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:58:17,556] Trial 26 finished with value: -300.0 and parameters: {'gamma': 0.0004705877190887067, 'buffer_size ': 100000, 'lr': 2.5394704902101727e-05, 'max_grad_norm': 2.9542213610448136, 'batch_size': 64, 'net_arch': 'small', 'activation_fn': 'relu', 'seed ': 4}. Best is trial 6 with value: 95.0.
# [I 2022-04-19 22:58:35,468] Trial 27 finished with value: 82.33333333333333 and parameters: {'gamma': 0.002412684156061744, 'buffer_size ': 1000, 'lr': 0.0011893986200722858, 'max_grad_norm': 0.7284822446429858, 'batch_size': 32, 'net_arch': 'small', 'activation_fn': 'tanh', 'seed ': 1}. Best is trial 6 with value: 95.0.
# Number of finished trials:  28
# Best trial:
#   Value:  95.0
#   Params:
#     gamma: 0.0021813151695808546
#     buffer_size : 100000
#     lr: 0.00015581771449402266
#     max_grad_norm: 2.8095652180149444
#     batch_size: 64
#     net_arch: small
#     activation_fn: tanh
#     seed : 1
#   User attrs:
#     gamma_: 0.9978186848304191

# %% [markdown]
# ## Create and train our tuned model

# %% [markdown]
# Having completed our hyperparameter search, we plug in the hyperparameters generated from the search into our model along with the network archtecture values.

# %% [markdown]
# We supply the searched network architecture, orth_init and activation function using policy kwargs

# %%
policy_kwargs = dict(    
    activation_fn = th.nn.Tanh,
    net_arch = [32,32,64],
)

# %% [markdown]
# Create our model using searched hyperparameters and policy kwargs

# %%
model = DQN("CnnPolicy", env, tensorboard_log=LOG_DIR, verbose=1,
           gamma = 0.9978186848304191, max_grad_norm = 2.8095652180149444,
           buffer_size = 100000, learning_rate = 0.00015581771449402266,
           batch_size = 64,seed = 1,optimize_memory_usage = True, policy_kwargs=policy_kwargs)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# Train our agent using a specified number of timesteps

# %%
model.learn(total_timesteps=100000,callback=callback)
# Out:
# Logging to ./train/log_basic3\DQN_9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 293      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 772      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 111      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.5     |
# |    ep_rew_mean      | -46.2    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 949      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | -18.2    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 949      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 339      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | -48      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 998      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | -36.5    |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 982      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | -27.2    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 987      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 988      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | -26.3    |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1011     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 842      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1010     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | -25.9    |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1025     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1012     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | -40.8    |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1017     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | -41.1    |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1013     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | -44.3    |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1012     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1009     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | -46.6    |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1020     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | -43.8    |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1018     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | -45.4    |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1024     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1022     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | -50.5    |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1027     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.1     |
# |    ep_rew_mean      | -47.3    |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1024     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | -48.1    |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1027     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.3     |
# |    ep_rew_mean      | -48.4    |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1030     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.7     |
# |    ep_rew_mean      | -52      |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1012     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | -58.1    |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1016     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | -60.5    |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1020     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | -57.9    |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1027     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | -64.8    |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1031     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | -63.5    |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1037     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | -74.6    |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1046     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | -77.8    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1047     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -87.7    |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1048     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | -94.6    |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1052     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1053     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.7     |
# |    ep_rew_mean      | -99.7    |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1053     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.3     |
# |    ep_rew_mean      | -97.7    |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1055     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | -96.8    |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1056     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -94.1    |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1041     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | -88.7    |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1041     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -86.8    |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1039     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4994     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | -81.8    |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1031     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -85.6    |
# |    exploration_rate | 0.501    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1031     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1034     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -89      |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1033     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.5     |
# |    ep_rew_mean      | -80.8    |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1035     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -87.8    |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1037     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -88.3    |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1017     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -88.2    |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1013     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -86.7    |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1009     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.1     |
# |    ep_rew_mean      | -82.8    |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1009     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1011     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -86.6    |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1013     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | -84.1    |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1011     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.8     |
# |    ep_rew_mean      | -86      |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1005     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.4     |
# |    ep_rew_mean      | -77.7    |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1005     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | -77      |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1007     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | -71.5    |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1008     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.8     |
# |    ep_rew_mean      | -66.2    |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1011     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | -72.4    |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1012     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -76.2    |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 986      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | -73.2    |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 986      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.2     |
# |    ep_rew_mean      | -70.5    |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 986      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | -77.3    |
# |    exploration_rate | 0.226    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 985      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | -77.3    |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 985      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | -81.5    |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 986      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | -81.5    |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 973      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -77.5    |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 974      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | -67.3    |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 973      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | -68.8    |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 974      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | -70.2    |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 976      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | -65.6    |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 969      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | -69.3    |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 970      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | -65.4    |
# |    exploration_rate | 0.146    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 970      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | -60.8    |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 969      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | -58.2    |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 968      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.7     |
# |    ep_rew_mean      | -54.6    |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 968      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | -49.2    |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 968      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | -44.9    |
# |    exploration_rate | 0.114    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 968      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | -35.9    |
# |    exploration_rate | 0.11     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 968      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | -36.9    |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 969      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 971      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | -35.6    |
# |    exploration_rate | 0.0786   |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 972      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.0591   |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 975      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | -28.7    |
# |    exploration_rate | 0.0504   |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 976      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | -17.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 974      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -11.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 973      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | -14.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 974      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | -7.06    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 974      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -10.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 971      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 973      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 975      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | -23.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 972      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | -28.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 973      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | -31.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 974      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | -38.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 977      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | -41.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 979      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | -34.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 980      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | -37.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 980      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | -35.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 980      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | -49.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 978      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.9     |
# |    ep_rew_mean      | -54.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 975      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.5     |
# |    ep_rew_mean      | -52.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 975      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | -55.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 976      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | -64.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 978      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | -65      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 980      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.2     |
# |    ep_rew_mean      | -68.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 982      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | -69.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 982      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | -66.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 983      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | -68.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 985      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.2     |
# |    ep_rew_mean      | -69.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 984      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | -71.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 984      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | -71.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 985      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | -72.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 975      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -78.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 978      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.5     |
# |    ep_rew_mean      | -82      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 979      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.2     |
# |    ep_rew_mean      | -73.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 980      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.3     |
# |    ep_rew_mean      | -74.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 981      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.7     |
# |    ep_rew_mean      | -75      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 981      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | -83      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 982      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.7     |
# |    ep_rew_mean      | -74.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 981      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.3     |
# |    ep_rew_mean      | -85      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 984      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.6     |
# |    ep_rew_mean      | -86.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 984      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -93.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 985      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    time_elapsed     | 632      |
# |    total_timesteps  | 80634    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.46     |
# |    n_updates        | 7658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.5     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 126      |
# |    time_elapsed     | 638      |
# |    total_timesteps  | 80934    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 4.37     |
# |    n_updates        | 7733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.5     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 125      |
# |    time_elapsed     | 645      |
# |    total_timesteps  | 81234    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.687    |
# |    n_updates        | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 125      |
# |    time_elapsed     | 650      |
# |    total_timesteps  | 81468    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.35     |
# |    n_updates        | 7866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 124      |
# |    time_elapsed     | 656      |
# |    total_timesteps  | 81768    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 1.93     |
# |    n_updates        | 7941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 123      |
# |    time_elapsed     | 662      |
# |    total_timesteps  | 82068    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 5.88     |
# |    n_updates        | 8016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 123      |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 82346    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.595    |
# |    n_updates        | 8086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 122      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 82646    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.762    |
# |    n_updates        | 8161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 121      |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 82946    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 5.92     |
# |    n_updates        | 8236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 121      |
# |    time_elapsed     | 686      |
# |    total_timesteps  | 83246    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.4      |
# |    n_updates        | 8311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 120      |
# |    time_elapsed     | 692      |
# |    total_timesteps  | 83546    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 4.39     |
# |    n_updates        | 8386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 119      |
# |    time_elapsed     | 698      |
# |    total_timesteps  | 83846    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.76     |
# |    n_updates        | 8461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.3     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 119      |
# |    time_elapsed     | 703      |
# |    total_timesteps  | 84074    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 4.12     |
# |    n_updates        | 8518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.3     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 118      |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 84374    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.28     |
# |    n_updates        | 8593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.3     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 118      |
# |    time_elapsed     | 715      |
# |    total_timesteps  | 84674    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.01     |
# |    n_updates        | 8668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.2     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 117      |
# |    time_elapsed     | 722      |
# |    total_timesteps  | 84974    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.65     |
# |    n_updates        | 8743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.7     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 117      |
# |    time_elapsed     | 728      |
# |    total_timesteps  | 85274    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.58     |
# |    n_updates        | 8818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 116      |
# |    time_elapsed     | 733      |
# |    total_timesteps  | 85574    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.35     |
# |    n_updates        | 8893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.3     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 116      |
# |    time_elapsed     | 739      |
# |    total_timesteps  | 85874    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 7.56     |
# |    n_updates        | 8968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.2     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 115      |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 86174    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.35     |
# |    n_updates        | 9043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.7     |
# |    ep_rew_mean      | -235     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 115      |
# |    time_elapsed     | 750      |
# |    total_timesteps  | 86430    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.758    |
# |    n_updates        | 9107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.6     |
# |    ep_rew_mean      | -251     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 114      |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 86730    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.895    |
# |    n_updates        | 9182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | -262     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 114      |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 87030    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.738    |
# |    n_updates        | 9257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.6     |
# |    ep_rew_mean      | -271     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 113      |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 87330    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 2.28     |
# |    n_updates        | 9332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.8     |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 113      |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 87630    |
# | train/              |          |
# |    learning_rate    | 0.000156 |
# |    loss             | 0.327    |
# |    n_updates        | 9407     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-3000ab6e0ff5> in <module>
# ----> 1 model.learn(total_timesteps=100000,callback=callback)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     256     ) -> OffPolicyAlgorithm:
#     257
# --> 258         return super(DQN, self).learn(
#     259             total_timesteps=total_timesteps,
#     260             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     352
#     353         while self.num_timesteps < total_timesteps:
# --> 354             rollout = self.collect_rollouts(
#     355                 self.env,
#     356                 train_freq=self.train_freq,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     585
#     586             # Rescale and perform action
# --> 587             new_obs, rewards, dones, infos = env.step(actions)
#     588
#     589             self.num_timesteps += env.num_envs
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      41     def step_wait(self) -> VecEnvStepReturn:
#      42         for env_idx in range(self.num_envs):
# ---> 43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44                 self.actions[env_idx]
#      45             )
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      88         if self.needs_reset:
#      89             raise RuntimeError("Tried to step environment that needs reset")
# ---> 90         observation, reward, done, info = self.env.step(action)
#      91         self.rewards.append(reward)
#      92         if done:
#
# <ipython-input-5-a4a9c0cf1543> in step(self, action)
#      31         #this actions will be a matrix defining if the agent go left,
#      32         #right or shoot and also our frame skip parameter
# ---> 33         reward = self.game.make_action(actions[action],4)
#      34
#      35         #return numpy zeroes array if nothing is returned
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test and evaluate our model

# %% [markdown]
# We will evaluate our model in the video game environment to determine its performance

# %% [markdown]
# We load our best trained model to use for evaluation

# %%
model = PPO.load('./train/train_basic2/best_model_80000')

# %% [markdown]
# Create and render our environment to see the agents performance

# %% [markdown]
# Create and render our environment to see the agents performance

# %%
env = VizDoomGym(render=True)

# %%
#loop through each game
for episode in range(10):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
